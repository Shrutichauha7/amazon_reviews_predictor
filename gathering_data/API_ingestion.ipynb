# %%
# !pip install requests pandas numpy matplotlib seaborn nltk scikit-learn
# Out:
# Requirement already satisfied: requests in c:\users\lenovo\pycharmprojects\amazon_reviews_predictor\.venv\lib\site-packages (2.32.5)
# Requirement already satisfied: pandas in c:\users\lenovo\pycharmprojects\amazon_reviews_predictor\.venv\lib\site-packages (3.0.1)
# Requirement already satisfied: numpy in c:\users\lenovo\pycharmprojects\amazon_reviews_predictor\.venv\lib\site-packages (2.4.2)
# Requirement already satisfied: matplotlib in c:\users\lenovo\pycharmprojects\amazon_reviews_predictor\.venv\lib\site-packages (3.10.8)
# Requirement already satisfied: seaborn in c:\users\lenovo\pycharmprojects\amazon_reviews_predictor\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: nltk in c:\users\lenovo\pycharmprojects\amazon_reviews_predictor\.venv\lib\site-packages (3.9.3)
# Requirement already satisfied: scikit-learn in c:\users\lenovo\pycharmprojects\amazon_reviews_predictor\.venv\lib\site-packages (1.8.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\lenovo\pycharmprojects\amazon_reviews_predictor\.venv\lib\site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\pycharmprojects\amazon_reviews_predictor\.venv\lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\pycharmprojects\amazon_reviews_predictor\.venv\lib\site-packages (from requests) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\pycharmprojects\amazon_reviews_predictor\.venv\lib\site-packages (from requests) (2026.2.25)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lenovo\pycharmprojects\amazon_reviews_predictor\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\lenovo\pycharmprojects\amazon_reviews_predictor\.venv\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lenovo\pycharmprojects\amazon_reviews_predictor\.venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\lenovo\pycharmprojects\amazon_reviews_predictor\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lenovo\pycharmprojects\amazon_reviews_predictor\.venv\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\lenovo\pycharmprojects\amazon_reviews_predictor\.venv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\lenovo\pycharmprojects\amazon_reviews_predictor\.venv\lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in c:\users\lenovo\pycharmprojects\amazon_reviews_predictor\.venv\lib\site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in c:\users\lenovo\pycharmprojects\amazon_reviews_predictor\.venv\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: click in c:\users\lenovo\pycharmprojects\amazon_reviews_predictor\.venv\lib\site-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in c:\users\lenovo\pycharmprojects\amazon_reviews_predictor\.venv\lib\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\lenovo\pycharmprojects\amazon_reviews_predictor\.venv\lib\site-packages (from nltk) (2026.2.19)
# Requirement already satisfied: tqdm in c:\users\lenovo\pycharmprojects\amazon_reviews_predictor\.venv\lib\site-packages (from nltk) (4.67.3)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\lenovo\pycharmprojects\amazon_reviews_predictor\.venv\lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\lenovo\pycharmprojects\amazon_reviews_predictor\.venv\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\pycharmprojects\amazon_reviews_predictor\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: colorama in c:\users\lenovo\pycharmprojects\amazon_reviews_predictor\.venv\lib\site-packages (from click->nltk) (0.4.6)
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests
import pandas as pd

API_KEY = "1f4f81d815msh1de024253902da4p1adefdjsn6a9292a1adaf"
API_HOST ="real-time-amazon-data.p.rapidapi.com"

# %%
def fetch_reviews(asin="B00939I7EK", pages=2):

    url = "https://real-time-amazon-data.p.rapidapi.com/product-reviews"

    headers = {
        "X-RapidAPI-Key": API_KEY,
        "X-RapidAPI-Host": "real-time-amazon-data.p.rapidapi.com"
    }

    all_reviews = []

    for page in range(1, pages + 1):

        params = {
            "asin": asin,
            "country": "US",
            "sort_by": "TOP_REVIEWS",
            "page": str(page)
        }

        response = requests.get(url, headers=headers, params=params)

        print("Status:", response.status_code)

        if response.status_code == 200:
            data = response.json()

            # IMPORTANT: This API nests reviews inside data
            reviews = data.get("data", {}).get("reviews", [])

            for review in reviews:
                all_reviews.append({
                    "review_text": review.get("review_comment"),
                    "rating": review.get("review_star_rating"),
                })

        else:
            print("Error:", response.text)



    return pd.DataFrame(all_reviews)

# %%
df = fetch_reviews(asin="B00939I7EK", pages=1)
df.head()
# Out:
# Status: 200
#                                          review_text rating
# 0  The Ninja Kitchen System has been an amazing a...      5
# 1  The Ninja Mega Kitchen System is excellent qua...      5
# 2  We love this blender and food processor. It’s ...      5
# 3  I love this! It is so powerful and works amazi...      5
# 4  Such a good blender. Smoothie cups are a go-to...      5

# %%
df.to_csv("amazon_reviews_raw.csv", index=False)

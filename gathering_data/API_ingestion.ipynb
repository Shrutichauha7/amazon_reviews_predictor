# %%
# !pip install requests pandas numpy matplotlib seaborn nltk scikit-learn
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests
import pandas as pd

API_KEY = "1f4f81d815msh1de024253902da4p1adefdjsn6a9292a1adaf"
API_HOST ="real-time-amazon-data.p.rapidapi.com"

# %%
def fetch_reviews(asin="B00939I7EK", pages=2):

    url = "https://real-time-amazon-data.p.rapidapi.com/product-reviews"

    headers = {
        "X-RapidAPI-Key": API_KEY,
        "X-RapidAPI-Host": "real-time-amazon-data.p.rapidapi.com"
    }

    all_reviews = []

    for page in range(1, pages + 1):

        params = {
            "asin": asin,
            "country": "US",
            "sort_by": "TOP_REVIEWS",
            "page": str(page)
        }

        response = requests.get(url, headers=headers, params=params)

        print("Status:", response.status_code)

        if response.status_code == 200:
            data = response.json()

            # IMPORTANT: This API nests reviews inside data
            reviews = data.get("data", {}).get("reviews", [])

            for review in reviews:
                all_reviews.append({
                    "review_text": review.get("review_comment"),
                    "rating": review.get("review_star_rating"),
                })

        else:
            print("Error:", response.text)



    return pd.DataFrame(all_reviews)

# %%
df = fetch_reviews(asin="B00939I7EK", pages=1)
df.head()
# Out:
# Status: 500
# Error: {"status":"ERROR","request_id":"a038ada5-6dbb-4fe3-b51e-e1393e09a8e1","error":{"message":"An unknown error has occurred","code":500}}
# Empty DataFrame
# Columns: []
# Index: []

# %%
df.to_csv("amazon_reviews_raw.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df.to_csv("amazon_reviews_raw.csv", index=False)
#
# NameError: name 'df' is not defined

# %%
df.info()
df.head()
df.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   review_text  8 non-null      str
#  1   rating       8 non-null      str
# dtypes: str(2)
# memory usage: 260.0 bytes
# review_text    0
# rating         0
# dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.shape
#
# NameError: name 'df' is not defined
